# %%
#Tuple are ordered collection of elements, heterogenous 
#Tuple are immutable

# %%
t = ()
type(t)
# Out:
# tuple

# %%
t = ("pwskills", "Ajay", 2, 2.3, True, 3+5j)
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 'pwskills'

# %%
#Tuples are immutable
t[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Tuples are immutable
# ----> 2 t[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
empid= (1,2,3,4,5)
empid[1] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 empid= (1,2,3,4,5)
# ----> 2 empid[1] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple1 = ("pwskills",1,1,1,2,2)
tuple1.count(1)
# Out:
# 3

# %%
tuple1.index("pwskills")
# Out:
# 0

# %%
print(tuple1 * 2)
# Out:
# ('pwskills', 1, 1, 1, 2, 2, 'pwskills', 1, 1, 1, 2, 2)

# %%
tuple1[0:4]
# Out:
# ('pwskills', 1, 1, 1)

# %%
tuple1[::-1]
# Out:
# (2, 2, 1, 1, 1, 'pwskills')

# %%
for i in tuple1: 
    print(i)
# Out:
# pwskills
# 1
# 1
# 1
# 2
# 2

# %%
for i in tuple1: 
    print(i, type(i))
# Out:
# pwskills <class 'str'>
# 1 <class 'int'>
# 1 <class 'int'>
# 1 <class 'int'>
# 2 <class 'int'>
# 2 <class 'int'>

# %%
t1 = (1,2,100,0,200)
max(t1)
# Out:
# 200

# %%
min(t1)
# Out:
# 0

# %%
t2=(101,201)
t3 = (t1,t2) 
t3           #Nested Tuple
# Out:
# ((1, 2, 100, 0, 200), (101, 201))

# %%
del t3

# %%
t3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 t3
#
# NameError: name 't3' is not defined

# %%
len(t1)
# Out:
# 5

# %%
1 in t1
# Out:
# True

# %%
"pwskills" not in tuple1
# Out:
# False

# %%
#Combination of bith the tuple
t1+t2
# Out:
# (1, 2, 100, 0, 200, 101, 201)

# %%
#SETS>> sets are unordered and unique collection of elements
#doesn't allow duplicate elements
#unordered>> indexing will not work

# %%
s = {}
type(s)
# Out:
# dict

# %%
s = {1}
type(s)
# Out:
# set

# %%
s = {1,2,1,2,"Ajay","ajay","Ajay","ajay"}
s
# Out:
# {1, 2, 'Ajay', 'ajay'}

# %%
#USE CASE
list1 = [1,2,3,"Brinjal","Apple", "Apple"]
s= set(list1)
s
# Out:
# {1, 2, 3, 'Apple', 'Brinjal'}

# %%
new_list = list(s)
new_list
# Out:
# [1, 2, 3, 'Brinjal', 'Apple']

# %%
s[0]        #Not indexed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s = {1,2,3,4,5,{4,5,6}}             #set inside set must be immutable. Immutable data structure has stable hash value, like tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 s = {1,2,3,4,5,{4,5,6}}
#
# TypeError: cannot use 'set' as a set element (unhashable type: 'set')

# %%
{1,2,3,4,5,(4,5,6)}             #It didn't throw error, because tuple is immutable>> stable hash type
# Out:
# {(4, 5, 6), 1, 2, 3, 4, 5}

# %%
s = {1,2,3,4}
for i in s:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
#Set is mutable
s.add(100)          #not compulsory that it will add to the last of set
s
# Out:
# {1, 2, 3, 4, 100}

# %%
s.pop()             #It is not compulsory that it will remove the last element
# Out:
# 1

# %%
s.remove(3)             #It removes specifically

# %%
s
# Out:
# {2, 4, 100}

# %%
s.pop(3)            #It removes randomly
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 s.pop(3)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
s.update("Ajay")
s
# Out:
# {100, 2, 4, 'A', 'a', 'j', 'y'}

# %%
s.update(["Ajay"])
s
# Out:
# {100, 2, 4, 'A', 'Ajay', 'a', 'j', 'y'}

# %%
s.update([2,3])
s
# Out:
# {100, 2, 3, 4, 'A', 'Ajay', 'a', 'j', 'y'}

# %%
s={(1,2,3),100,'2',3.4}
type(s)
# Out:
# set

# %%
s.clear()
s
# Out:
# set()

# %%
del s

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
s = {(1,2,3),100,101,102,'2',3.4}
s
# Out:
# {(1, 2, 3), 100, 101, 102, '2', 3.4}

# %%
s.remove(101)

# %%
s
# Out:
# {(1, 2, 3), 100, 102, '2', 3.4}

# %%
s.remove(110)           #Throws an error as 110 is not present
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 s.remove(110)
#
# KeyError: 110

# %%
s.discard(100)
s
# Out:
# {(1, 2, 3), 102, '2', 3.4}

# %%
s.discard(110)                          #Error will not be thrown unlikely remove if the element is not present
s
# Out:
# {(1, 2, 3), 102, '2', 3.4}

# %%
#SET OPERATIONS

s1 = {"hiking", "reading","coding"}
s2 = {"coding","photography", "travelling" }

# %%
#Union
s1 | s2
# Out:
# {'coding', 'hiking', 'photography', 'reading', 'travelling'}

# %%
#Intersection>> Common element
s1 & s2
# Out:
# {'coding'}

# %%
#Difference
s1-s2
# Out:
# {'hiking', 'reading'}

# %%
#Symmetric difference
s1^s2
# Out:
# {'hiking', 'photography', 'reading', 'travelling'}

# %%
#Frozen Set

s = {1,2,3}
s.add(100)
s
# Out:
# {1, 2, 3, 100}

# %%
#Frozen Set>> immutable version of set, cannot be added or removed any new element

my_fs = frozenset([1,2,2,3,4,4,5])
my_fs
# Out:
# frozenset({1, 2, 3, 4, 5})

# %%
type(my_fs)
# Out:
# frozenset

# %%
my_fs.add(5,6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 my_fs.add(5,6)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
my_fs.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 my_fs.pop()
#
# AttributeError: 'frozenset' object has no attribute 'pop'
