# %%
#String is a sequence of characters where each character is a single unit of text whcih is helpful to represent and manipulate textual data.
#Characters are represented using numerical values >> each character is assigned a unique value.
# ASCII(7 bits) and UNICODE (16 bits) >> 2 to power 7 
# 128 characters has been encoded whereas UTF is 2 to power 16 almost covered every character of every language

#UTF-8 , UTF-16>> popular encoding schemes for unicode>> widely accepted in industry
#ASCII >> American Standard Code For Information Interchange
#UTF >> Unicode Transformation Format

# %%
#ASCII representation
char = "A"
ord(char)                       #ord>> ordinal, means what is numerical order of character
# Out:
# 65

# %%
ord("a")
# Out:
# 97

# %%
#UNICODE representation
#omega

'\u03A9'
# Out:
# 'Ω'

# %%
'\u0973'
# Out:
# 'ॳ'

# %%
#strings 
string1 = "pwskills"
string1
# Out:
# 'pwskills'

# %%
'I'm a student'
# Out:
#   Cell In[7], line 1
#     'I'm a student'
#                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"I'm a student"
# Out:
# "I'm a student"

# %%
"I"m a student"
# Out:
#   Cell In[9], line 1
#     "I"m a student"
#                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"""I"m a student"""
# Out:
# 'I"m a student'

# %%
'''I'm a student
I study in pwskills
I am a data scientist'''
# Out:
# "I'm a student\nI study in pwskills\nI am a data scientist"

# %%
#concatenation of string >> combination of two string

"Hello" + " World"
# Out:
# 'Hello World'

# %%
string1 = "hello"
string2 = "world!"
string1 + "," + string2
# Out:
# 'hello,world!'

# %%
"string" + ">>" + "concatenation"
# Out:
# 'string>>concatenation'

# %%
#EXTRACT / SLICING OF STRING
a = "Ajay"
a[0]
# Out:
# 'A'

# %%
string1 = "I am a good student"
string1[0:4]                        #4 is exclusive [a,b] >> it will give result till b-1 index
# Out:
# 'I am'

# %%
string1[5:12]
# Out:
# 'a good '

# %%
string1[0:]          #start index : end index >> if you not provide end index, it will be default give substring till the last index
# Out:
# 'I am a good student'

# %%
#Except the last three character
strings2 = "pwskills"
strings2[:-3]
# Out:
# 'pwski'

# %%
#you want only last characters
strings2[-3:]
# Out:
# 'lls'

# %%
string2 = "hello world!"
string2[0:5:1]          #by default step is 1
# Out:
# 'hello'

# %%
string2[0:5:2]
# Out:
# 'hlo'

# %%
string2[::2]
# Out:
# 'hlowrd'

# %%
#iterate over the sequence in reverse order 
#it means start from the end, move to the beginning a dstep backwards by one character
string2[::-1]
# Out:
# '!dlrow olleh'

# %%
s = "pwskills"
s[0]
# Out:
# 'p'

# %%
s[0] = "a"              # strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 s[0] = "a"              # strings are immutable
#
# TypeError: 'str' object does not support item assignment

# %%
len(s)          #number of character
# Out:
# 8

# %%
s = "I am a good student"
len(s)
# Out:
# 19

# %%
#MODIFICATION OF STRING
s + "I am a student"
s.replace("student", "teacher")         #modification
# Out:
# 'I am a good teacher'

# %%
#USE CASE 
address = "123 suhana apt, Marathalli, Bangalore"
address.replace("apt", "apartment")
# Out:
# '123 suhana apartment, Marathalli, Bangalore'

# %%
text = "BRB, TTYL, LOL"
text.replace("BRB", "Be right back").replace("TTYL", "Talk to you later"). replace("LOL", "Laughing out loud")
# Out:
# 'Be right back, Talk to you later, Laughing out loud'

# %%
text = "Hello World"
text.lower()        #lower case
# Out:
# 'hello world'

# %%
text.upper()        #upper case
# Out:
# 'HELLO WORLD'

# %%
text= "I am a Student"
text.title()    #First letter of each word
# Out:
# 'I Am A Student'

# %%
text.swapcase()             #small to capital and capital to small
# Out:
# 'i AM A sTUDENT'

# %%
text.capitalize()           #only the first letter of the sentence is capitalized
# Out:
# 'I am a student'

# %%
#STRING SEARCHING
sentence = "I am a student at pwskills"
"am" in sentence
# Out:
# True

# %%
sentence = "I am a student at pwskills"
search_word = "am"
if search_word in sentence : 
    print("The search word is present")
else:
    print("Not present")
# Out:
# The search word is present

# %%
email = "Anu123"
if "@" in email:
    print("valid email")
else:
    print("Invalid Email")
# Out:
# Invalid Email

# %%
document = "text.pdf"
if ".pdf" in document:
    print("It is a document file")
else:
    print ("Not valid document")

# %%
#STRING COMPARISON
str1 = "hello"
str2 = "hello"
str1 == str2
# Out:
# True

# %%
str1 = "Hello"                  #python is case sensitive
str2 = "hello"
str1 == str2
# Out:
# False

# %%
str1.lower() == str2.lower()
# Out:
# True

# %%
reg_username = ["pw", "PW", "pW"]
new_user = "PW1"
if new_user in reg_username:
    print("already in use")
else:
    print("username is available")
# Out:
# username is available

# %%
product_code = "P123"
scanned_code = input("scan the product code")
print("scanned_code is", scanned_code)
if product_code == scanned_code:
    print("The price is 100")
else:
    print("Talk to receptionist")
# Out:
# scanned_code is P124
# Talk to receptionist

# %%
#STRING ORDERING
name = ["Anurag", "Harsh", "Dheeraj"]
sorted(name)
# Out:
# ['Anurag', 'Dheeraj', 'Harsh']

# %%
playlist = ["KKRH", "Magic", "Singham", "Alishan"]
sorted(playlist)
# Out:
# ['Alishan', 'KKRH', 'Magic', 'Singham']

# %%
#Common String Operators
input_str = "               pw                      "
input_str
# Out:
# '               pw                      '

# %%
input_str.strip()           #Strip removes the leading and trailing whitespaces
# Out:
# 'pw'

# %%
#STRING SPLITTING
data ="Ajay, data science, teacher"
data
# Out:
# 'Ajay, data science, teacher'

# %%
teacher_info = data.split(',')
teacher_info
# Out:
# ['Ajay', ' data science', ' teacher']

# %%
name = teacher_info[0]
subject = teacher_info[1]
des = teacher_info[2]

# %%
name
# Out:
# 'Ajay'

# %%
subject
# Out:
# ' data science'

# %%
des
# Out:
# ' teacher'
