# %%
#Data structure >> It is a way of organizing and storing data so that it can be accessed and manipulated efficiently

# %%
#List >> You can store anything in list>> can store heterogenous data
#List is an ordered collection of elements that can be of any data type
#Lists are mutable

# %%
num = [1 ,2 ,3 ,4 ,5]
num
# Out:
# [1, 2, 3, 4, 5]

# %%
type(num)
# Out:
# list

# %%
num[0]
# Out:
# 1

# %%
num[-3]
# Out:
# 3

# %%
num[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 num[5]
#
# IndexError: list index out of range

# %%
a = [1 ,2 ,3.3, "baigan", "tomato", "banana", True, False, 3+7j]

#List can store any data type>> heterogenous data structure
a
# Out:
# [1, 2, 3.3, 'baigan', 'tomato', 'banana', True, False, (3+7j)]

# %%
a.append("pwskills") #adding element the list
a
# Out:
# [1, 2, 3.3, 'baigan', 'tomato', 'banana', True, False, (3+7j), 'pwskills']

# %%
a.remove("pwskills")        #removes the value
a
# Out:
# [1, 2, 3.3, 'baigan', 'tomato', 'banana', True, False, (3+7j)]

# %%
#list inside list
lis = [[1,2,3], [4,5,6], [7,8,9]]
lis
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
type(lis)
# Out:
# list

# %%
#accessing the 6 in 1st index

lis[1][2]
# Out:
# 6

# %%
#list is mutable
shopping_list = ["Brinjal", "Apple", 2, 3.4, True]
shopping_list[0] = "Potato"
shopping_list
# Out:
# ['Potato', 'Apple', 2, 3.4, True]

# %%
for item in shopping_list:
    print(item, end = " ")
# Out:
# Potato Apple 2 3.4 True

# %%
#Tuple >> () parenthesis
#Tuples are immutable

point = (2, 3)
point
# Out:
# (2, 3)

# %%
type(point)
# Out:
# tuple

# %%
#use case >> ADHAAR card, employ ID, atm>> you don't want to change, you will use tuple to store data
#tuple>>heterogenous data

t = (1, 2, 3.3 , True, 3+5j, "Ajay")
type(t)
# Out:
# tuple

# %%
t
# Out:
# (1, 2, 3.3, True, (3+5j), 'Ajay')

# %%
emp_name = ("Ajay", "Ajay1", "Bijay", "Sanjay")
type(emp_name)
# Out:
# tuple

# %%
emp_name[1]
# Out:
# 'Ajay1'

# %%
emp_name[2] = "Rahul"           #Tuple are immmutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 emp_name[2] = "Rahul"
#
# TypeError: 'tuple' object does not support item assignment

# %%
box1 = ("a" , "b")
box2 = ("c" , "d")
choc_bag = (box1, box2)
choc_bag
# Out:
# (('a', 'b'), ('c', 'd'))

# %%
for box in choc_bag:
    for choc in box:
        print(choc)
# Out:
# a
# b
# c
# d

# %%
# Sets --> {} >> are unordered collection of unique element
s = {"red", "orange"}
type(s)
# Out:
# set

# %%
s = {"red", "orange", "blue", "red", "orange", 1, 2 ,3.3}
s
# Out:
# {1, 2, 3.3, 'blue', 'orange', 'red'}

# %%
s[0]        #error>> no concept of of indexing as sets are unordered and unique
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 s[0]        #error>> no concept of of indexing as sets are unordered and unique
#
# TypeError: 'set' object is not subscriptable

# %%
s.add("pwskills")           #sets are mutable
s
# Out:
# {1, 2, 3.3, 'blue', 'orange', 'pwskills', 'red'}

# %%
s.remove(3.3)
s
# Out:
# {1, 2, 'blue', 'orange', 'pwskills', 'red'}

# %%
#Use Case of sets>> to get unique elements
grocery_list = {"apple", "banana", "banana", "eggs", "eggs"}
grocery_list
# Out:
# {'apple', 'banana', 'eggs'}

# %%
#Dictionaries >> which stores data in the form of key value pair

# %%
my_dict = {}
type(my_dict)
# Out:
# dict

# %%
my_dict = {"key_course": "data science", "duartion": 200}
my_dict
# Out:
# {'key_course': 'data science', 'duartion': 200}

# %%
#Use Case

phonebook = {"dad" : 12344, "mom":6788}
phonebook
# Out:
# {'dad': 12344, 'mom': 6788}

# %%
phonebook["dad"]
# Out:
# 12344

# %%
phonebook = {"dad" : 12344, "mom":6788, "dad" :68997}
phonebook
# Out:
# {'dad': 68997, 'mom': 6788}

# %%
rest_menu = {"paneer_kofta": 480, "chicken_handi" : 590}
rest_menu
# Out:
# {'paneer_kofta': 480, 'chicken_handi': 590}

# %%
rest_menu['paneer_kofta'] = 790
rest_menu
# Out:
# {'paneer_kofta': 790, 'chicken_handi': 590}

# %%
phonebook["dad"] = "I have taken a new no. again, I don't want to tell u"
phonebook
# Out:
# {'dad': "I have taken a new no. again, I don't want to tell u", 'mom': 6788}

# %%
rest_menu.keys()
# Out:
# dict_keys(['paneer_kofta', 'chicken_handi'])

# %%
phonebook.keys()
# Out:
# dict_keys(['dad', 'mom'])

# %%
rest_menu.values()
# Out:
# dict_values([790, 590])

# %%
phonebook.values()
# Out:
# dict_values(["I have taken a new no. again, I don't want to tell u", 6788])

# %%
# Array >> It is similar to list >> homogenous data

#String
s = "Ajay"
type(s)
# Out:
# str

# %%
for i in s:
    print(i)
# Out:
# A
# j
# a
# y

# %%
s[0] = "b"          #strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s[0] = "b"          #strings are immutable
#
# TypeError: 'str' object does not support item assignment
